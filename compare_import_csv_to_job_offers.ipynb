# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 500)

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# csvの読み取り
# df= pd.read_csv("/kaggle/input/jobs-old/jobs_utf8.csv")
# これをカラム名にする
# col_names = [ 'c{0:02d}'.format(i) for i in range(108) ]
  #=> ['c00', 'c01', 'c02', 'c03', 'c04', 'c05', 'c06', 'c07', 'c08', 'c09']
    
# df_csv = pd.read_csv( './jobs_utf8_8.csv', encoding="utf-8", names=col_names, usecols=['c00', 'c01', 'c05'], low_memory=False )

# %%
# csvの読み取り
# df= pd.read_csv("/kaggle/input/jobs-old/jobs_utf8.csv")
# これをカラム名にする
col_names = [ 'c{0:02d}'.format(i) for i in range(108) ]
  #=> ['c00', 'c01', 'c02', 'c03', 'c04', 'c05', 'c06', 'c07', 'c08', 'c09']
    
df_csv = pd.read_csv( './jobs_utf8.csv', encoding="utf-8", names=col_names, usecols=['c00', 'c01', 'c05'], low_memory=False )

# %%
# csvの読み取り
# df= pd.read_csv("/kaggle/input/jobs-old/jobs_utf8.csv")
# これをカラム名にする
# col_names = [ 'c{0:02d}'.format(i) for i in range(108) ]
  #=> ['c00', 'c01', 'c02', 'c03', 'c04', 'c05', 'c06', 'c07', 'c08', 'c09']
    
# df_csv = pd.read_csv( './jobs_utf8_8.csv', encoding="utf-8", names=col_names, low_memory=False )

# %%
print(df_csv.shape)
# Out:
# (571544, 3)

# %%
# df_csv[df_csv["c00"] == "13244588"]
print(df_csv[df_csv['c05'].str.contains('ネクストレベル', na=False)])
# Out:
#              c00     c01                                   c05
# 280     13353205  mynavi  株式会社ネクストレベル大阪西日本本社 ※勤務地：神戸市中央区三宮駅エリア
# 281     13353203  mynavi  株式会社ネクストレベル大阪西日本本社 ※勤務地：京都市下京区京都駅エリア
# 81365   13185331  mynavi                           ネクストレベル株式会社
# 122145  13102177  mynavi        株式会社ネクストレベル 福岡支店 ※勤務地：北九州市八幡西区
# 122146  13102175  mynavi   株式会社ネクストレベル 福岡支店 ※勤務地：北九州市小倉北区小倉駅周辺
# ...          ...     ...                                   ...
# 257173  12594165  mynavi          株式会社ネクストレベル名古屋支店　※岡崎市東岡崎駅エリア
# 257174  12594163  mynavi              株式会社ネクストレベル名古屋支店　※岡崎市エリア
# 257175  12594161  mynavi              株式会社ネクストレベル名古屋支店　※稲沢市エリア
# 257176  12594159  mynavi              株式会社ネクストレベル名古屋支店　※一宮駅エリア
# 257177  12594157  mynavi            株式会社ネクストレベル名古屋支店　※三河安城駅エリア
#
# [1016 rows x 3 columns]

# %%
df_csv[df_csv['c05'].str.contains('ネクストレベル', na=False)].shape
# Out:
# (1016, 3)

# %%
# ネクストレイト
df_csv[df_csv["c00"] == "13587671"]
# Out:
#             c00     c01         c05
# 29877  13587671  mynavi  株式会社フリージョン

# %%
# 株式会社綜合キャリアオプション
df_csv[df_csv["c00"] == "13306793"]
# Out:
#             c00      c01     c02       c03                              c04  \
# 22970  13306793  baitoru  138500  49865917  【優良企業×高収入】加工パーツの測定/週払いOK&履歴書不要！
#
#                         c05  c06     c07     c08   c09  \
# 22970  株式会社綜合キャリアオプション　東広島店  NaN  1200.0  1200.0  1300
#
#                                                      c10  \
# 22970  マシンの操作のお仕事です。機械への材料供給・部品交換・目視検査・測定器具を使用した検査・運搬...
#
#                                                      c11  \
# 22970  マシンの操作のお仕事です。機械への材料供給・部品交換・目視検査・測定器具を使用した検査・運搬...
#
#                                                      c12 c13   c14  c15  c16  \
# 22970  工場<br />[派遣]製造スタッフ(組立・加工等)、ライン作業、仕分け・シール貼り<br ...   1  1100  NaN  NaN
#
#        c17  c18  c19    c20      c21 c22    c23  \
# 22970  NaN  NaN  NaN  広島県呉市  広島県呉市近郊  34  34202
#
#                                    c24  \
# 22970  [派遣]08:30〜17:30<br />8:30〜17:30
#
#                                                      c25  c26 c27  c28  \
# ...

# %%
# mynaviとbaitoruのデータだけ抽出
df_csv_import = df_csv.query('c01 in ["mynavi", "baitoru"]')

# %%
df_csv_import.head()
# Out:
#           c00     c01           c02                     c03  \
# 206  13353353  mynavi  002658302527  J0033995360S0001250733
# 207  13353351  mynavi  002658302527  J0033995358S0001250733
# 208  13353349  mynavi  002059806906  J0034009644S0005152364
# 209  13353347  mynavi  002059806906  J0034007680S0005152386
# 210  13353345  mynavi  002059806906  J0034007654S0005152360
#
#                                                    c04  \
# 206     レストランSTAFF (≪苫小牧駅〜徒歩4分≫ホテル内の和食店◎着物風のカワイイ制服あり♪)
# 207  宴会サービスSTAFF (&lt;週2〜OK◎&gt;友達と一緒に楽しく★時給900円！登録...
# 208         保育補助 (登録制★短期or長期OK！全額週払いOKの案件アリ◎選べる勤務地色々♪)
# 209        保育補助STAFF (≪入社日相談OK≫土日祝休み★無資格＆実務未経験でも働けます♪)
# 210         一般事務 (登録制★短期or長期OK！全額週払いOKの案件アリ◎選べる勤務地色々♪)
#
#                                       c05            c06     c07  c08  c09  \
# 206                          グランドホテルニュー王子  グランドホテルニューオウジ   400.0  NaN  NaN
# 207                          グランドホテルニュー王子  グランドホテルニューオウジ   400.0  NaN  NaN
# ...

# %%
df_csv_import.shape
# Out:
# (367306, 108)

# %%
df_csv_import[df_csv_import["c00"] == "13244588"]
# Out:
#             c00      c01
# 52492  13244588  baitoru

# %%
df_csv_import.dtypes
# Out:
# c00    object
# c01    object
# dtype: object

# %%
df_csv_import['c00'] = df_csv_import['c00'].astype(str).astype(int)
# df_csv_import[["c00"]]=df_csv_import[["c00"]].fillna(0.0).astype(int)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_csv_import.dtypes
# Out:
# c00     int64
# c01    object
# dtype: object

# %%
# phpmyadminのjob_offersテーブルのダンプCSVデータを読み込み
df_job_offers = pd.read_csv( './job_offers3.csv', names=['job_offer_id', 'client_cd'],  low_memory=False )

# %%
print(df_job_offers.shape)
# Out:
# (327165, 2)

# %%
df_job_offers.head()
# Out:
#    job_offer_id client_cd
# 0       4704939    mynavi
# 1       4877687    mynavi
# 2       5557791    mynavi
# 3       5629157    mynavi
# 4       5681403    mynavi

# %%
df_job_offers.dtypes
# Out:
# job_offer_id     int64
# client_cd       object
# dtype: object

# %%
df_diff = df_job_offers[~df_job_offers['job_offer_id'].isin(df_csv_import['c00'])]

# %%
df_diff.shape
# Out:
# (45, 2)

# %%
df_diff.head()
# Out:
#        job_offer_id client_cd
# 21265      10522452   baitoru
# 22300      10527629   baitoru
# 22322      10527679   baitoru
# 41961      10761860   baitoru
# 45143      10937768   baitoru

# %%
df_diff
# Out:
#         job_offer_id client_cd
# 21265       10522452   baitoru
# 22300       10527629   baitoru
# 22322       10527679   baitoru
# 41961       10761860   baitoru
# 45143       10937768   baitoru
# 50433       11323472   baitoru
# 50434       11323474   baitoru
# 50435       11323475   baitoru
# 50436       11323476   baitoru
# 50437       11323478   baitoru
# 50438       11323482   baitoru
# 50439       11323486   baitoru
# 50440       11323492   baitoru
# 50441       11323494   baitoru
# 50443       11323555   baitoru
# 50444       11323556   baitoru
# 50445       11323557   baitoru
# 50446       11323560   baitoru
# 50447       11323564   baitoru
# 50448       11323565   baitoru
# 50449       11323566   baitoru
# 50450       11323569   baitoru
# 50451       11323574   baitoru
# 86884       12172389   baitoru
# 88450       12248734   baitoru
# 88451       12248735   baitoru
# 169290      12555271    mynavi
# 169292      12555279    mynavi
# 169294      12555285    mynavi
# ...

# %%
df_diff2 = df_csv_import[~df_csv_import['c00'].isin(df_job_offers['job_offer_id'])]

# %%
df_diff2.shape
# Out:
# (1, 2)

# %%
df_diff2
# Out:
#         c00      c01
# 2  13159717  baitoru

# %%
# csvの読み取り
# df= pd.read_csv("/kaggle/input/jobs-old/jobs_utf8.csv")
# これをカラム名にする
col_names = [ 'c{0:02d}'.format(i) for i in range(108) ]
  #=> ['c00', 'c01', 'c02', 'c03', 'c04', 'c05', 'c06', 'c07', 'c08', 'c09']
    
df_csv2 = pd.read_csv( './jobs_utf8_4.csv', encoding="utf-8", names=col_names, low_memory=False )

# %%
df_csv2[df_csv2["c00"] == "13159717"]
# Out:
#         c00      c01     c02       c03                               c04  \
# 0  13159717  baitoru  173620  50068170  ☆オープニング★初登場！20~30代活躍の営業事務スタッフ募集！
#
#          c05  c06     c07     c08   c09  \
# 0  株式会社ビーホープ  NaN  1000.0  1000.0  1000
#
#                                                  c10  \
# 0  ＼*オープニング営業事務*／<BR><BR>20〜30代の女性スタッフさん大活躍！<BR>一...
#
#                                                  c11  \
# 0  ＼*オープニング営業事務*／<BR><BR>20〜30代の女性スタッフさん大活躍！<BR>一...
#
#                                                  c12 c13   c14  c15  c16  c17  \
# 0  [派遣]営業事務、一般事務職、データ入力、タイピング(PC・パソコン・インターネット)<br...   1  1050  NaN  NaN  NaN
#
#    c18  c19       c20       c21 c22    c23                          c24  \
# 0  NaN  NaN  大阪府大阪市西区  大阪府大阪市西区  27  27106  [派遣]08:30〜17:30、09:00〜17:30
#
#                                              c25  c26  c27  c28   c29  c30  \
# 0  大阪市営地下鉄中央線本町駅 徒歩 5分<br />大阪市営地下鉄中央線阿波座駅 徒歩 7分  NaN  200  060  派遣事業  NaN
#
# ...
