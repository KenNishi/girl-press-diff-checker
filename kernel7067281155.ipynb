# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 500)

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# csvの読み取り
# df= pd.read_csv("/kaggle/input/jobs-old/jobs_utf8.csv")
# これをカラム名にする
col_names = [ 'c{0:02d}'.format(i) for i in range(108) ]
  #=> ['c00', 'c01', 'c02', 'c03', 'c04', 'c05', 'c06', 'c07', 'c08', 'c09']

# ガロアからもらったCSVを読み込み
# df_csv = pd.read_csv( './jobs.csv', encoding="cp932", names=col_names, low_memory=False )

df_csv = pd.read_csv( './jobs_utf8.csv', encoding="utf-8", names=col_names, usecols=['c00', 'c01'], low_memory=False )

# %%
print(df_csv.shape)
# Out:
# (503973, 2)

# %%
df_csv.head()
# Out:
#         c00       c01
# 0  13140353  jukunavi
# 1  13140351  jukunavi
# 2  13140349  jukunavi
# 3  13140347  jukunavi
# 4  13140345  jukunavi

# %%
# mynaviとbaitoruのデータだけ抽出
df_csv_import = df_csv.query('c01 in ["mynavi", "baitoru"]')

# %%
df_csv_import.head()
# Out:
#            c00     c01
# 1719  13137003  mynavi
# 1720  13137001  mynavi
# 1721  13136999  mynavi
# 1722  13136997  mynavi
# 1723  13136995  mynavi

# %%
df_csv_import.shape
# Out:
# (324870, 2)

# %%
# phpmyadminのjob_offersテーブルのダンプCSVデータを読み込み
df_job_offers = pd.read_csv( './job_offers.csv', names=col_names,  low_memory=False )

# %%
# phpmyadminのwp_postsテーブルのダンプCSVデータを読み込み
df_wp_posts = pd.read_csv( './wp_posts.csv', names=col_names,  low_memory=False )

# %%
df_job_offers.head()
# Out:
#        c00     c01         c02                     c03  \
# 0  4704939  mynavi  1303209058  J0025712738S0001740059
# 1  4877687  mynavi  2831804354  J0025942462S0003916432
# 2  5557791  mynavi  2049102968  J0026594964S0002093589
# 3  5629157  mynavi  2396602275  J0026650072S0001464541
# 4  5681403  mynavi  2584104661  J0026761608S0000057214
#
#                                                  c04                  c05  \
# 0     ホール＆キッチン (週1〜OK!シフト・髪型・髪色自由◎マスクもOK★町田の人気店で働く♪)             ひろしま鉄ちゃん
# 1  コールSTAFF ((*゜ー゜)激ヤバ!!＼誰でも高時給1500円／週2〜★髪&amp;ネイ...     株式会社トラストコーポレーション
# 2  店舗STAFF (時給大幅UP!!≫人気の個人店♪[同時募集]ラーメン店のオープニングSTA...  牛タン焼海鮮炉端焼　田舎家酒房　藩次郎
# 3       店舗スタッフ (★駅近3分★《週2日〜、1日3.5hでOK◎》食事補助＆有給休暇あり！)       さくら市場館府中フォーリス店
# 4  人力車での観光案内 (&lt;週2〜3&gt;Welcome to Ebisuya！その英語...             えびす屋　浅草店
#
#     c06   c07  c08  c09                                                c10  \
# 0   NaN   100  NaN  NaN  *＊。本場広島の味をご提供♪。＊*<br>お話好きの方♪*<br>⇒鉄ちゃんに向いています◎...
# ...

# %%
df_wp_posts.head()
# Out:
#    c00  c01                  c02                  c03  \
# 0    2    1  2017-06-08 19:37:06  2017-06-08 19:37:06
# 1   32    1  2017-06-07 01:59:51  2017-06-06 16:59:51
# 2   37    1  2017-04-29 14:31:05  0000-00-00 00:00:00
# 3   87    1  2017-05-14 02:17:24  2017-05-13 17:17:24
# 4  121    1  2017-05-16 12:53:34  2017-05-16 03:53:34
#
#                                                  c04  \
# 0  これはサンプルページです。同じ位置に固定され、(多くのテーマでは) サイトナビゲーションメニ...
# 1  <![CDATA[<h3>仕事内容</h3>\n短期・単発のお仕事多数!!\n○サンプリング...
# 2  <table id="wysija_wrapper" border="0" width="1...
# 3  <![CDATA[<h3>仕事内容</h3>\n小学生と一緒にキャンプに行き、\n子どもたち...
# 4  <table>\r\n<tbody>\r\n<tr>\r\n<th>会社名</th>\r\n...
#
#                                             c05  c06      c07     c08     c09  \
# 0                                       サンプルページ  NaN  private  closed    open
# 1  簡単業務で大人気★月1日～OK!!高時給・短期のレアバイト★勤務地はご自宅近くでご用意！  NaN    trash    open    open
# 2                                           NaN  NaN    draft  closed  closed
# ...

# %%
df_job_offers_min = df_job_offers[['c00', 'c01']]

# %%
df_wp_posts_min = df_wp_posts[['c00', 'c23']]

# %%
print(df_job_offers_min.shape)
# Out:
# (324456, 2)

# %%
print(df_wp_posts_min.shape)
# Out:
# (326441, 2)

# %%
df_job_offers_min.head()
# Out:
#        c00     c01
# 0  4704939  mynavi
# 1  4877687  mynavi
# 2  5557791  mynavi
# 3  5629157  mynavi
# 4  5681403  mynavi

# %%
df_wp_posts_min.head()
# Out:
#    c00  c23
# 0    2  NaN
# 1   32  NaN
# 2   37  NaN
# 3   87  NaN
# 4  121  NaN

# %%
df_wp_posts_min = df_wp_posts_min[np.isfinite(df_wp_posts_min['c23'])]

# %%
print(df_wp_posts_min.shape)
# Out:
# (324456, 2)

# %%
df_wp_posts_min.head()
# Out:
#           c00         c23
# 1984  9822488  12736151.0
# 1985  9822489  12736141.0
# 1986  9822490  12736140.0
# 1987  9822491  12736139.0
# 1988  9822497  12736133.0

# %%
df_diff = df_job_offers_min[~df_job_offers_min['c00'].isin(df_wp_posts_min['c23'])]

# %%
df_diff.shape
# Out:
# (0, 2)

# %%
df_diff.head()
# Out:
# Empty DataFrame
# Columns: [c00, c01]
# Index: []

# %%
df_diff2 = df_wp_posts_min[~df_wp_posts_min['c23'].isin(df_job_offers_min['c00'])]

# %%
df_diff2.shape
# Out:
# (0, 2)

# %%
df_diff3 = df_job_offers_min[~df_job_offers_min['c00'].isin(df_csv_import['c00'])]

# %%
df_diff3.shape
# Out:
# (2542, 2)

# %%
df_diff4 = df_csv_import[~df_csv_import['c00'].isin(df_job_offers_min['c00'])]

# %%
df_diff4.shape
# Out:
# (324870, 2)

# %%
df_diff2.to_csv("df_diff2.csv")
